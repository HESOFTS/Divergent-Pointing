# %%
# %load_ext autoreload
# %autoreload 2

# %%
from ctadiv.ArrayConfig import *

# %% [markdown]
# ### Load a CTA configuration

# %%
array = LoadConfig("./config/layout-3AL4M15-5.txt")

# %% [markdown]
# ### Check table

# %%
array.table
# Out:
# <Table length=19>
#   id     x       y       z     focal  ...   p_x     p_y     p_z    d_tel
#          m       m       m       m    ...                            m
# int64 float64 float64 float64 float64 ... float64 float64 float64 float64
# ----- ------- ------- ------- ------- ... ------- ------- ------- -------
#     1  -70.04   -7.23    54.0    28.0 ...   1.000  -0.000   0.000   34.63
#     2  -34.37  110.98    43.0    28.0 ...   1.000  -0.000   0.000   94.18
#     3   76.18   95.34    39.7    28.0 ...   1.000  -0.000   0.000  166.98
#     4   31.81   -19.7    43.0    28.0 ...   1.000  -0.000   0.000  117.20
#     5 -210.65   50.51    61.3    16.0 ...   1.000  -0.000   0.000  137.60
#     6 -179.06  223.02    42.1    16.0 ...   1.000  -0.000   0.000  222.09
#     7   27.96  243.56    23.2    16.0 ...   1.000  -0.000   0.000  241.86
#     8  176.27   127.9    19.3    16.0 ...   1.000  -0.000   0.000  273.21
#     9  124.21 -134.56    39.6    16.0 ...   1.000  -0.000   0.000  256.94
#    10  -74.73 -144.16    53.2    16.0 ...   1.000  -0.000   0.000  170.79
#    11 -214.79 -122.52    74.1    16.0 ...   1.000  -0.000   0.000  205.43
#    12  -98.11  376.45    20.7    16.0 ...   1.000  -0.000   0.000  351.74
#    13   21.08 -307.61    73.3    16.0 ...   1.000  -0.000   0.000  348.76
#    14  -196.4 -290.24    88.1    16.0 ...   1.000  -0.000   0.000  341.27
#    15     0.9   44.85    40.0    16.0 ...   1.000  -0.000   0.000   79.27
#    16 -302.85   384.6     3.3    16.0 ...   1.000  -0.000   0.000  426.47
#    17  -345.0   175.0    69.0    16.0 ...   1.000  -0.000   0.000  308.14
#    18 -374.99  -33.39    92.6    16.0 ...   1.000  -0.000   0.000  308.33
#    19  204.28 -267.84    53.0    16.0 ...   1.000  -0.000   0.000  406.31

# %% [markdown]
# ### Activate the divergent pointing mode

# %%
array.divergent_pointing(div = 0.1, az_mean = -180, alt_mean = 70)
# Out:
# [Warning] The unit of the input alt is assumed to be 'deg'
# [Warning] The unit of the input az is assumed to be 'deg'

# %% [markdown]
# ### Check the average of the telescope array location

# %%
utils.calc_mean(array.table, ["x", "y", "z"])
# Out:
# [-75.7, 26.576842105263164, 49.078947368421055]

# %% [markdown]
# ### Check the average of the telescope pointing vector

# %%
utils.calc_mean(array.table, ["p_x", "p_y", "p_z"])
# Out:
# [-0.32746890361223013, 0.0012304696596896366, 0.9017618358368387]

# %% [markdown]
# ### Convert radians to degrees

# %%
array.convert_unit(deg=True)
# Out:
# <Table length=19>
#   id     x       y       z     focal  ...   p_x     p_y     p_z    d_tel
#          m       m       m       m    ...                            m
# int64 float64 float64 float64 float64 ... float64 float64 float64 float64
# ----- ------- ------- ------- ------- ... ------- ------- ------- -------
#     1  -70.04   -7.23    54.0    28.0 ...  -0.335   0.034   0.942   34.63
#     2  -34.37  110.98    43.0    28.0 ...  -0.305  -0.086   0.948   94.18
#     3   76.18   95.34    39.7    28.0 ...  -0.199  -0.073   0.977  166.98
#     4   31.81   -19.7    43.0    28.0 ...  -0.243   0.048   0.969  117.20
#     5 -210.65   50.51    61.3    16.0 ...  -0.448  -0.023   0.894  137.60
#     6 -179.06  223.02    42.1    16.0 ...  -0.424  -0.188   0.886  222.09
#     7   27.96  243.56    23.2    16.0 ...  -0.245  -0.225   0.943  241.86
#     8  176.27   127.9    19.3    16.0 ...  -0.097  -0.111   0.989  273.21
#     9  124.21 -134.56    39.6    16.0 ...  -0.148   0.170   0.974  256.94
#    10  -74.73 -144.16    53.2    16.0 ...  -0.335   0.169   0.927  170.79
#    11 -214.79 -122.52    74.1    16.0 ...  -0.443   0.138   0.886  205.43
#    12  -98.11  376.45    20.7    16.0 ...  -0.350  -0.337   0.874  351.74
#    13   21.08 -307.61    73.3    16.0 ...  -0.233   0.320   0.918  348.76
#    14  -196.4 -290.24    88.1    16.0 ...  -0.410   0.282   0.867  341.27
#    15     0.9   44.85    40.0    16.0 ...  -0.274  -0.019   0.962   79.27
#    16 -302.85   384.6     3.3    16.0 ...  -0.509  -0.321   0.798  426.47
#    17  -345.0   175.0    69.0    16.0 ...  -0.534  -0.130   0.836  308.14
#    18 -374.99  -33.39    92.6    16.0 ...  -0.546   0.051   0.836  308.33
#    19  204.28 -267.84    53.0    16.0 ...  -0.061   0.299   0.952  406.31

# %% [markdown]
# ### Check the ICRS coordinate of the pointing

# %%
array.frame.info
array.pointing_coord(icrs=True)
# Out:
# Observer        :  Roque
# Location        :  Roque de los Muchachos (5327.44899578, -1718.6657387, 3051.56690295) km
# Observation time:  2013-11-01T03:00:00.000
# <SkyCoord (ICRS): (ra, dec) in deg
#     [(65.52733718,  9.12340601), (72.52460657, 10.85343606),
#      (71.84066762, 17.18174231), (64.62590572, 14.6388769 ),
#      (68.79677544,  2.08489161), (78.32981437,  3.13427084),
#      (80.8860138 , 13.78578959), (74.38268131, 23.01451386),
#      (57.09089853, 19.7866615 ), (57.67530679,  8.72192713),
#      (59.58558629,  2.16175781), (87.3444202 ,  6.54077962),
#      (48.25994   , 13.68280035), (51.08943109,  3.24125002),
#      (68.6033496 , 12.83093393), (86.29654185, -3.58989527),
#      (74.99027258, -3.78350665), (64.56489612, -4.43984127),
#      (48.41680413, 23.81267942)]>

# %% [markdown]
# ### Display the telescope pointing

# %% [markdown]
# #### 1D

# %%
array.display("x", group=False)
# Out:
# <AxesSubplot:xlabel='x [m]'>

# %% [markdown]
# #### 2D

# %%
array.display("xz", group=True)
# Out:
# <AxesSubplot:xlabel='x [m]', ylabel='z [m]'>

# %% [markdown]
# #### 3D

# %%
array.display("xyz", group=True)
